# %% [markdown]
# <a href="https://colab.research.google.com/github/mineozcan/UMBC-DATA609-FALL24-WANG/blob/main/Assignments/assigment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 10/16/2024

# %%
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

print(df.shape)
df.sample(3)
# Out:
# (4123, 9)
#       Year               Country  GDP per capita (current US$)  \
# 2563  2021            Mozambique                    504.037787
# 3601  2014  Syrian Arab Republic                   1071.234204
# 1012  2009               Denmark                  58163.276876
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2563                                59.325000         32077072.0          MOZ
# 3601                                63.153000         20072232.0          SYR
# 1012                                78.597561          5523095.0          DNK
#
#                           Region Income Group    Lending Type
# 2563         Sub-Saharan Africa    Low income             IDA
# 3601  Middle East & North Africa   Low income             IDA
# 1012       Europe & Central Asia  High income  Not classified

# %%
column_names_dict = {
    "GDP per capita (current US$)" : "GDP per Capita",
    "Life expectancy at birth, total (years)" : "Life Expectancy",
    "Population, total" : "Population"
}

df = df.rename(columns=column_names_dict)
df.sample(3)
# Out:
#       Year               Country  GDP per Capita  Life Expectancy  Population  \
# 3880  2008  United Arab Emirates    45140.769077           77.488   6988685.0
# 848   2016      Congo, Dem. Rep.      456.027951           59.066  81430977.0
# 3797  2020          Turkmenistan     7330.366288           68.687   6250438.0
#
#      Country Code                      Region         Income Group  \
# 3880          ARE  Middle East & North Africa          High income
# 848           COD         Sub-Saharan Africa            Low income
# 3797          TKM       Europe & Central Asia  Upper middle income
#
#         Lending Type
# 3880  Not classified
# 848              IDA
# 3797            IBRD

# %%
df.sample(3).T
# Out:
#                                   2072                   1902  \
# Year                              2005                   2006
# Country                         Latvia             Kazakhstan
# GDP per Capita             7594.902384            5291.574004
# Life Expectancy              71.356098                  66.15
# Population                   2238799.0             15308085.0
# Country Code                       LVA                    KAZ
# Region           Europe & Central Asia  Europe & Central Asia
# Income Group               High income    Upper middle income
# Lending Type            Not classified                   IBRD
#
#                                   80
# Year                              2008
# Country                        Andorra
# GDP per Capita            53721.388507
# Life Expectancy                    NaN
# Population                     76055.0
# Country Code                       AND
# Region           Europe & Central Asia
# Income Group               High income
# Lending Type            Not classified

# %% [markdown]
# ## Section One
#
# Summary Statistics with describe() function

# %%
df[["Population","Life Expectancy"]].describe()
# Out:
#          Population  Life Expectancy
# count  4.123000e+03      3777.000000
# mean   3.319575e+07        71.060853
# std    1.316430e+08         8.499806
# min    9.791000e+03        42.125000
# 25%    7.436200e+05        65.351000
# 50%    5.872624e+06        72.765000
# 75%    2.148494e+07        77.529000
# max    1.417173e+09        85.497561

# %%
df.describe()
# Out:
#              Year  GDP per Capita  Life Expectancy    Population
# count  4123.00000     3962.000000      3777.000000  4.123000e+03
# mean   2013.00000    17007.692848        71.060853  3.319575e+07
# std       5.47789    25733.109164         8.499806  1.316430e+08
# min    2004.00000      128.538423        42.125000  9.791000e+03
# 25%    2008.00000     1862.892400        65.351000  7.436200e+05
# 50%    2013.00000     6048.304202        72.765000  5.872624e+06
# 75%    2018.00000    22137.309568        77.529000  2.148494e+07
# max    2022.00000   240862.182448        85.497561  1.417173e+09

# %%
df.describe(include="object")
# Out:
#             Country Country Code                 Region Income Group  \
# count          4123         4123                   4123         4123
# unique          217          217                      7            5
# top     Afghanistan          AFG  Europe & Central Asia  High income
# freq             19           19                   1102         1558
#
#           Lending Type
# count             4123
# unique               4
# top     Not classified
# freq              1387

# %%
df.describe(include="object").T
# Out:
#              count unique                    top  freq
# Country       4123    217            Afghanistan    19
# Country Code  4123    217                    AFG    19
# Region        4123      7  Europe & Central Asia  1102
# Income Group  4123      5            High income  1558
# Lending Type  4123      4         Not classified  1387

# %% [markdown]
# ## Section Two
#
# Compute quartiles and transform a numerical column into a categorical column based on the quartiles.

# %%
def assign_quartile(gdp):
    if gdp <= 1862.89:
        quartile = "1st Quartile (<=25%)"
    elif gdp > 1862.89 and gdp <= 6048.30:
        quartile = "2nd Quartile (25-50%)"
    elif gdp > 6048.30 and gdp <= 22137.31:
        quartile = "3rd Quartile (50-75%)"
    else:
        quartile = "4th Quartile (>75%)"
    return quartile


hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile (50-75%)'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per Capita  Life Expectancy   Population  \
# 3914  2004  United States    41724.631629        77.487805  292805298.0
# 3915  2005  United States    44123.407068        77.487805  295516599.0
# 3916  2006  United States    46302.000880        77.687805  298379912.0
# 3917  2007  United States    48050.223777        77.987805  301231207.0
# 3918  2008  United States    48570.045980        78.039024  304093966.0
# 3919  2009  United States    47194.943355        78.390244  306771529.0
# 3920  2010  United States    48650.643128        78.541463  309327143.0
# 3921  2011  United States    50065.966504        78.641463  311583481.0
# 3922  2012  United States    51784.418574        78.741463  313877662.0
# 3923  2013  United States    53291.127689        78.741463  316059947.0
# 3924  2014  United States    55123.849787        78.841463  318386329.0
# 3925  2015  United States    56762.729452        78.690244  320738994.0
# 3926  2016  United States    57866.744934        78.539024  323071755.0
# 3927  2017  United States    59907.754261        78.539024  325122128.0
# 3928  2018  United States    62823.309438        78.639024  326838199.0
# 3929  2019  United States    65120.394663        78.787805  328329953.0
# 3930  2020  United States    63528.634303        76.980488  331511512.0
# 3931  2021  United States    70219.472454        76.329268  332031554.0
# 3932  2022  United States    76329.582265              NaN  333287557.0
#
#      Country Code         Region Income Group    Lending Type
# 3914          USA  North America  High income  Not classified
# 3915          USA  North America  High income  Not classified
# 3916          USA  North America  High income  Not classified
# 3917          USA  North America  High income  Not classified
# 3918          USA  North America  High income  Not classified
# 3919          USA  North America  High income  Not classified
# 3920          USA  North America  High income  Not classified
# 3921          USA  North America  High income  Not classified
# 3922          USA  North America  High income  Not classified
# 3923          USA  North America  High income  Not classified
# 3924          USA  North America  High income  Not classified
# 3925          USA  North America  High income  Not classified
# 3926          USA  North America  High income  Not classified
# 3927          USA  North America  High income  Not classified
# 3928          USA  North America  High income  Not classified
# 3929          USA  North America  High income  Not classified
# 3930          USA  North America  High income  Not classified
# 3931          USA  North America  High income  Not classified
# 3932          USA  North America  High income  Not classified

# %%
assign_quartile(76329.58)
# Out:
# '4th Quartile (>75%)'

# %%
df_2020 = df[df["Year"] == 2020]
print(df_2020.shape[0])
print(f"There are {df_2020.shape[0]} countries in the 2020 dataset")
df_2020.sample(3)
# Out:
# 217
# There are 217 countries in the 2020 dataset
#       Year           Country  GDP per Capita  Life Expectancy  Population  \
# 187   2020             Aruba    24008.127822           75.723    106585.0
# 852   2020  Congo, Dem. Rep.      524.666686           59.739  92853164.0
# 3531  2020             Sudan      608.332520           65.614  44440486.0
#
#      Country Code                      Region Income Group    Lending Type
# 187           ABW  Latin America & Caribbean   High income  Not classified
# 852           COD         Sub-Saharan Africa    Low income             IDA
# 3531          SDN         Sub-Saharan Africa    Low income             IDA

# %%
# Tuple
df_2020.shape
# Out:
# (217, 9)

# %% [markdown]
# ## In-class Exercise
#
# Create a new column call "GDP Quartile" in the df_2020 dataframe and assign each country the quartile it belongs to by applying the assign_quartile() function.

# %%
df_2020["GDP Quartile"] = df_2020["GDP per Capita"].apply(assign_quartile)

print(df_2020.shape[0])
print(df_2020["GDP Quartile"].value_counts())
# Out:
# 217
# GDP Quartile
# 4th Quartile (>75%)      61
# 2nd Quartile (25-50%)    58
# 3rd Quartile (50-75%)    54
# 1st Quartile (<=25%)     44
# Name: count, dtype: int64

# %%
df_2020.sample(10)
# Out:
#       Year     Country  GDP per Capita  Life Expectancy   Population  \
# 966   2020     Curacao    16356.093325              NaN     154947.0
# 947   2020        Cuba     9499.572504        77.567000   11300698.0
# 985   2020      Cyprus    28281.425781        81.391000    1237537.0
# 3569  2020      Sweden    52837.903978        82.356098   10353442.0
# 2334  2020        Mali      822.906137        58.633000   21224040.0
# 1916  2020  Kazakhstan     9121.636409        71.370000   18755666.0
# 2429  2020      Mexico     8894.890650        70.133000  125998302.0
# 2144  2020     Liberia      597.529692        60.948000    5087584.0
# 301   2020  Bangladesh     2233.305901        71.968000  167420951.0
income
#
#         Lending Type           GDP Quartile  GDP (Rounded)  \
# 2676  Not classified    4th Quartile (>75%)          34878
# 1745            IBRD  2nd Quartile (25-50%)           2746
# 2296            IBRD  3rd Quartile (50-75%)          10164
# 814             IBRD  2nd Quartile (25-50%)           5304
# 3018  Not classified    4th Quartile (>75%)          31427
#
#       Population (Million)
# 2676              0.271080
# 1745             87.290193
# 2296             33.199993
# 814              50.930662
# 3018              3.281557

# %%
df_2020["Population2 (Million)"] = df_2020["Population"].apply(lambda pop : pop / 1000000)
df_2020.sample(5)
# Out:
#       Year                 Country  GDP per Capita  Life Expectancy  \
# 2410  2020               Mauritius     9011.042884        74.177073
# 1270  2020                    Fiji     4815.689148        67.924000
# 1080  2020      Dominican Republic     7167.914974        72.889000
# 4063  2020      West Bank and Gaza     3233.568638        74.403000
# 472   2020  Bosnia and Herzegovina     6095.104237        76.225000
#
#       Population Country Code                      Region  \
# 2410   1266014.0          MUS         Sub-Saharan Africa
# 1270    920422.0          FJI         East Asia & Pacific
# 1080  10999664.0          DOM  Latin America & Caribbean
# 4063   4803269.0          PSE  Middle East & North Africa
# 472    3318407.0          BIH       Europe & Central Asia
#
#              Income Group    Lending Type           GDP Quartile  \
# 2410  Upper middle income            IBRD  3rd Quartile (50-75%)
# 1270  Upper middle income           Blend  2nd Quartile (25-50%)
# 1080  Upper middle income            IBRD  3rd Quartile (50-75%)
# 4063  Upper middle income  Not classified  2nd Quartile (25-50%)
# 472   Upper middle income            IBRD  3rd Quartile (50-75%)
#
#       GDP (Rounded)  Population (Million)  Population2 (Million)
# 2410           9011              1.266014               1.266014
# 1270           4816              0.920422               0.920422
# 1080           7168             10.999664              10.999664
# 4063           3234              4.803269               4.803269
# 472            6095              3.318407               3.318407

# %% [markdown]
# ## Homework Question 1
#
# Save the summary statistics of all numerical columns and all categorical columns to only one Excel spreadsheet file with two worksheets, one for numerical and one for categorical columns.

# %%
# !pip install xlsxwriter
import pandas as pd
import xlsxwriter


df = pd.read_csv('https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv')

numerical_summary = df.describe()

categorical_summary = df.describe(include=['object', 'category'])

with pd.ExcelWriter('summary_statistics.xlsx', engine='xlsxwriter') as writer:
    numerical_summary.to_excel(writer, sheet_name='Numerical Columns')
    categorical_summary.to_excel(writer, sheet_name='Categorical Columns')
# Out:
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.10/dist-packages (3.2.0)

# %% [markdown]
# ## Homework Question 2
#
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round"
# Hint: apply the round function/method and provide a parameter 2.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv')

print(df.columns)

df["GDP (Rounded to 2 decimals)"] = df['GDP per capita (current US$)'].apply(lambda x: round(x, 2))

# Display a random sample of 5 rows from the DataFrame
df.sample(5)
# Out:
# Index(['Year', 'Country', 'GDP per capita (current US$)',
#        'Life expectancy at birth, total (years)', 'Population, total',
#        'Country Code', 'Region', 'Income Group', 'Lending Type'],
#       dtype='object')
#       Year     Country  GDP per capita (current US$)  \
# 878   2008  Costa Rica                   6841.911460
# 1830  2010       Italy                  36035.644995
# 1045  2004    Dominica                   5354.799195
# 377   2020      Belize                   5185.158070
# 1426  2005   Gibraltar                           NaN
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 878                                 78.445000          4501921.0          CRI
# 1830                                82.036585         59277417.0          ITA
# 1045                                72.401000            68574.0          DMA
# 377                                 72.854000           394921.0          BLZ
# 1426                                81.442000            29155.0          GIB
#
#                           Region         Income Group    Lending Type  \
# 878   Latin America & Caribbean   Upper middle income            IBRD
# 1830       Europe & Central Asia          High income  Not classified
# 1045  Latin America & Caribbean   Upper middle income           Blend
# 377   Latin America & Caribbean   Upper middle income            IBRD
# 1426       Europe & Central Asia          High income  Not classified
#
#       GDP (Rounded to 2 decimals)
# 878                       6841.91
# 1830                     36035.64
# 1045                      5354.80
# 377                       5185.16
# 1426                          NaN

# %%
x = 12.23456

y = round(x, 2)
y
# Out:
# 12.23

# %% [markdown]
# ## Homework Question 3 (bonus, will cover next week)
#
# step 1 - create a column "Life Expectancy Quartile" similar to the GDP per Capita Quartile above.
# Step 2 - Create a column "health and wealth status" based on the following definition
# - rich and healthy (1st GDP per capita quartile and 1st life expentancy quartile)
# - poor and unhealthy ((4th GDP per capita quartile and 4th life expentancy quartile)
# - rich and unhealthy (1st GDP per capita quartile and 4th life expentancy quartile)
# - poor and healthy ((4th GDP per capita quartile and 1st life expentancy quartile)
# - Other

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv')

print(df.columns)

df['Life Expectancy Quartile'] = pd.qcut(df['Life expectancy at birth, total (years)'], 4, labels=False) + 1

df['GDP per Capita Quartile'] = pd.qcut(df['GDP per capita (current US$)'], 4, labels=False) + 1

def determine_health_wealth_status(row):
  if row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 1:
      return 'rich and healthy'
  elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 4:
      return 'poor and unhealthy'
  elif row['GDP per Capita Quartile'] == 1 and row['Life Expectancy Quartile'] == 4:
      return 'rich and unhealthy'
  elif row['GDP per Capita Quartile'] == 4 and row['Life Expectancy Quartile'] == 1:
      return 'poor and healthy'
  else:
      return 'Other'

# Apply the function to create the new column
df['health and wealth status'] = df.apply(determine_health_wealth_status, axis=1)

print(df.sample(5))
# Out:
# Index(['Year', 'Country', 'GDP per capita (current US$)',
#        'Life expectancy at birth, total (years)', 'Population, total',
#        'Country Code', 'Region', 'Income Group', 'Lending Type'],
#       dtype='object')
#       Year                 Country  GDP per capita (current US$)  \
# 2827  2019                    Oman                  19132.152274
# 1937  2022                   Kenya                   2099.301938
# 472   2020  Bosnia and Herzegovina                   6095.104237
# 1670  2021                 Hungary                  18753.046945
# 1562  2008           Guinea-Bissau                    583.268306
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 2827                                78.002000          4602768.0          OMN
# 1937                                      NaN         54027487.0          KEN
# 472                                 76.225000          3318407.0          BIH
# 1670                                74.465854          9709891.0          HUN
# 1562                                54.646000          1488431.0          GNB
#
#                           Region         Income Group    Lending Type  \
# 2827  Middle East & North Africa          High income  Not classified
# 1937         Sub-Saharan Africa   Lower middle income           Blend
# 472        Europe & Central Asia  Upper middle income            IBRD
# 1670       Europe & Central Asia          High income  Not classified
# 1562         Sub-Saharan Africa            Low income             IDA
#
#       Life Expectancy Quartile  GDP per Capita Quartile  \
# 2827                       4.0                      3.0
# 1937                       NaN                      2.0
# 472                        3.0                      3.0
# 1670                       3.0                      3.0
# 1562                       1.0                      1.0
#
#      health and wealth status
# 2827                    Other
# 1937                    Other
# 472                     Other
# 1670                    Other
# 1562         rich and healthy
